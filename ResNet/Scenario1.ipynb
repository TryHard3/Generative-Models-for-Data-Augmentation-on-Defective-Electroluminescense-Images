# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend
from keras.layers import Embedding
from keras.layers import Concatenate

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot
from math import sqrt
from PIL import Image
import os

from numpy import load
from tensorflow.keras import backend

import shutil
import os
import cv2
import pickle as pkl
import numpy as np
from PIL import Image
import PIL
import numpy as np
import h5py
import scipy.io
import json
import PIL
import matplotlib.image as mpimg
from os import walk, getcwd
import glob
from functools import partial
from numpy import savetxt
from numpy import save

import matplotlib.pyplot as plt
from matplotlib import image
from PIL import Image
from matplotlib import pyplot as plt
import pandas as pd
from keras.initializers import RandomNormal
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, BatchNormalization, LeakyReLU, Dropout, ZeroPadding2D, UpSampling2D, Concatenate
from keras.layers import merge
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Model, Sequential
from keras import backend as K
from keras.optimizers import Adam, RMSprop
from keras.utils import plot_model
from PIL import Image
from tensorflow.python.framework.ops import disable_eager_execution, enable_eager_execution

# split a dataset into train and test sets
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from PIL import Image
from skimage.transform import resize
from sklearn.model_selection import train_test_split
import splitfolders

from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
import datetime
import os
import tensorflow_addons as tfa

# %%
#extract failure images
#Split failures into train, valid and test
#extract healthy images
#Split the healthy images into train, valid and test

# %% [markdown]
# ### Extract failure images

# %%
list = []

directory = r'C:\Users\lasse\Desktop\MainFolder\CrackedPictures\images'
os.chdir(directory) 
p = 0

for i in range(45701):
    img = cv2.imread(r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i)
    mat = scipy.io.loadmat(r'C:\Users\lasse\Desktop\SortedData2\labels\Label_%s.mat' % i)
    label = np.array(mat['GTLabel'])

    try:
        label = label[0][0][0]
    except:
        label = "No failure"
    
    if label == 'No failure':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\NoFailure\Image_%s.png' % i
        shutil.copyfile(original, target)
    elif label == 'Crack A':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\CrackA\Image_%s.png' % i
        shutil.copyfile(original, target)
    elif label == 'Crack B':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\CrackB\Image_%s.png' % i
        shutil.copyfile(original, target)
    elif label == 'Crack C':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\CrackC\Image_%s.png' % i
        shutil.copyfile(original, target)
    elif label == 'Finger Failure':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\FingerFailure\Image_%s.png' % i
        shutil.copyfile(original, target)
        
        #p = p + 1

# %% [markdown]
# ### Split failures into train, valid and test

# %% [markdown]
# Combining folders: FingerFailure/CrackA and CrackB/CrackC

# %%
#Training set: 70%
#Validation set: 20%
#Test set: 10%

def image_to_feature_vector(image, size=(256, 256)):
    return cv2.resize(image, size).flatten()

a = 0
list = []

Failure = 'FingerFailure'

length = len(os.listdir(r'C:\Users\lasse\Desktop\Dataset1\%s' % Failure))
print(length)
train = 0.7*length
validation = 0.9*length



for i in range(int(train)):
    img = cv2.imread(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i))
    if img is None:
        print(i)
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Train\%s\Image_%s.png' % (Failure, i))
for i in range(int(train), int(validation)):
    img = cv2.imread(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i))
    if img is None:
        print(i)
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Validation\%s\Image_%s.png' % (Failure, i))
for i in range(int(validation), length):
    img = cv2.imread(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i))
    if img is None:
        print(i)
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\Dataset1\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Test\%s\Image_%s.png' % (Failure, i))

print('Done')
# Out:
# 390
# 388
# 389
# Done

# %% [markdown]
# ### Extract healthy images

# %%
list = []

directory = r'C:\Users\lasse\Desktop\MainFolder\CrackedPictures\images'
os.chdir(directory) 
p = 0

for i in range(45701):
    img = cv2.imread(r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i)
    mat = scipy.io.loadmat(r'C:\Users\lasse\Desktop\SortedData2\labels\Label_%s.mat' % i)
    label = np.array(mat['GTLabel'])

    try:
        label = label[0][0][0]
    except:
        label = "No failure"
    
    if label == 'No failure':
        original = r'C:\Users\lasse\Desktop\SortedData2\images\Image_%s.png' % i
        target = r'C:\Users\lasse\Desktop\MainFolder\tilmappe\NoFailure\Image_%s.png' % i
        shutil.copyfile(original, target)
        
        #p = p + 1

# %% [markdown]
# ### Split the healthy images into train, valid and test

# %%
#Training set: 70%
#Validation set: 20%
#Test set: 10%

def image_to_feature_vector(image, size=(256, 256)):
    return cv2.resize(image, size).flatten()

a = 0
list = []

Failure = 'NoFailure'

length = 45701
print(length)
train = 0.7*length
validation = 0.9*length



for i in range(int(train)):
    img = cv2.imread(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i))
    if img is None:
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Train\%s\Image_%s.png' % (Failure, i))
for i in range(int(train), int(validation)):
    img = cv2.imread(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i))
    if img is None:
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Validation\%s\Image_%s.png' % (Failure, i))
for i in range(int(validation), length):
    img = cv2.imread(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i))
    if img is None:
    else:
        shutil.copy(r'C:\Users\lasse\Desktop\MainFolder\tilmappe\%s\Image_%s.png' % (Failure, i), r'C:\Users\lasse\Desktop\Resnets\ResNet1\Test\%s\Image_%s.png' % (Failure, i))

# %% [markdown]
# ## Building a CNN

# %%
def relu_bn(inputs: Tensor) -> Tensor:
    relu = ReLU()(inputs)
    bn = BatchNormalization()(relu)
    return bn

def residual_block(x: Tensor, downsample: bool, filters: int, kernel_size: int = 3) -> Tensor:
    y = Conv2D(kernel_size=kernel_size,
               strides= (1 if not downsample else 2),
               filters=filters,
               padding="same")(x)
    y = relu_bn(y)
    y = Conv2D(kernel_size=kernel_size,
               strides=1,
               filters=filters,
               padding="same")(y)

    if downsample:
        x = Conv2D(kernel_size=1,
                   strides=2,
                   filters=filters,
                   padding="same")(x)
    out = Add()([x, y])
    out = relu_bn(out)
    return out

def create_res_net():
    
    inputs = Input(shape=(256, 256, 3))
    num_filters = 64
    
    t = BatchNormalization()(inputs)
    t = Conv2D(kernel_size=3,
               strides=1,
               filters=num_filters,
               padding="same")(t)
    t = relu_bn(t)
    
    num_blocks_list = [2, 5, 5, 2]
    for i in range(len(num_blocks_list)):
        num_blocks = num_blocks_list[i]
        for j in range(num_blocks):
            t = residual_block(t, downsample=(j==0 and i!=0), filters=num_filters)
        num_filters *= 2
    
    t = AveragePooling2D(4)(t)
    t = Flatten()(t)
    outputs = Dense(3, activation='softmax')(t)
    
    model = Model(inputs, outputs)
    
    f1 = tfa.metrics.F1Score(3,'macro')
    
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy', f1]
    )
    return model

# %%
model = create_res_net() # or create_plain_net()
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 256, 256, 3)  12          input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 256, 256, 64) 1792        batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 256, 256, 64) 0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 256, 256, 64) 256         re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 256, 256, 64) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 256, 256, 64) 256         re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 256, 256, 64) 0           batch_normalization_31[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 256, 256, 64) 0           add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 256, 256, 64) 256         re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 256, 256, 64) 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 256, 256, 64) 256         re_lu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 64) 36928       batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 256, 256, 64) 0           batch_normalization_33[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 256, 256, 64) 0           add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 256, 256, 64) 256         re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 128 73856       batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 128, 128, 128 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 128 512         re_lu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 128 8320        batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 128, 128, 128 0           conv2d_39[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 128, 128, 128 0           add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 128 512         re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 128, 128, 128 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 128, 128, 128 512         re_lu_36[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 128, 128, 128 0           batch_normalization_37[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 128, 128, 128 0           add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 128, 128 512         re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 128, 128, 128 0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 128, 128, 128 512         re_lu_38[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 128, 128, 128 0           batch_normalization_39[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 128, 128, 128 0           add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 128, 128, 128 512         re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 128, 128, 128 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 128, 128, 128 512         re_lu_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 128, 128, 128 0           batch_normalization_41[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 128, 128, 128 0           add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 128, 128, 128 512         re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 128, 128, 128 0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 128, 128, 128 512         re_lu_42[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 128, 128, 128 147584      batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 128, 128, 128 0           batch_normalization_43[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 128, 128, 128 0           add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 128, 128, 128 512         re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 64, 256)  295168      batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 64, 64, 256)  0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 64, 64, 256)  1024        re_lu_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 256)  33024       batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 64, 256)  0           conv2d_50[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 64, 64, 256)  0           add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 64, 64, 256)  1024        re_lu_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 64, 64, 256)  0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64, 64, 256)  1024        re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 64, 64, 256)  0           batch_normalization_47[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 64, 64, 256)  0           add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 64, 256)  1024        re_lu_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 64, 64, 256)  0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 64, 64, 256)  1024        re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 64, 64, 256)  0           batch_normalization_49[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 64, 64, 256)  0           add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 64, 64, 256)  1024        re_lu_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 64, 64, 256)  0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 64, 64, 256)  1024        re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 64, 64, 256)  0           batch_normalization_51[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 64, 64, 256)  0           add_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 64, 64, 256)  1024        re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 64, 64, 256)  0           conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 64, 64, 256)  1024        re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 256)  590080      batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 64, 64, 256)  0           batch_normalization_53[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 64, 64, 256)  0           add_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64, 64, 256)  1024        re_lu_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 512)  1180160     batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 32, 32, 512)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 512)  2048        re_lu_54[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 512)  131584      batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 32, 32, 512)  0           conv2d_61[0][0]
#                                                                  conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 32, 32, 512)  0           add_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 512)  2048        re_lu_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 32, 32, 512)  0           conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 512)  2048        re_lu_56[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 512)  2359808     batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 32, 32, 512)  0           batch_normalization_57[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 32, 32, 512)  0           add_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 512)  2048        re_lu_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 512)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32768)        0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            98307       flatten_1[0][0]
# ==================================================================================================
# Total params: 15,713,167
# Trainable params: 15,700,745
# Non-trainable params: 12,422
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training the CNN

# %%
train_datagen = ImageDataGenerator(rescale=1./255, vertical_flip=True, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    directory=r"C:\Users\lasse\Desktop\Resnets\ResNet1\Test\\",
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=16,
    class_mode=None,
    shuffle=True,
    seed=42
)

valid_generator = test_datagen.flow_from_directory(
    directory=r"C:\Users\lasse\Desktop\Resnets\ResNet1\Validation\\",
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=16,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

train_generator = train_datagen.flow_from_directory(
    directory=r"C:\Users\lasse\Desktop\Resnets\ResNet1\Train\\",
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=16,
    class_mode="categorical",
    shuffle=True,
    seed=42
)
# Out:
# Found 4532 images belonging to 3 classes.
# Found 9065 images belonging to 3 classes.
# Found 31744 images belonging to 3 classes.

# %%
#Line that loads dataset and labels as train set and label set.
#(x_train, y_train), (x_test, y_test) = cifar10.load_data()

timestr = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
name = 'SOLARPANELS-'+timestr # or 'cifar-10_plain_net_30-'+timestr

checkpoint_path = "checkpoints/"+name+"/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
os.system('mkdir {}'.format(checkpoint_dir))

# save model after each epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1
)
tensorboard_callback = TensorBoard(
    log_dir='tensorboard_logs/'+name,
    histogram_freq=1
)

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size

#model.fit_generator(generator=train_generator,
#                    steps_per_epoch=STEP_SIZE_TRAIN,
#                    validation_data=valid_generator,
#                    validation_steps=STEP_SIZE_VALID,
#                    epochs=10,
#                    callbacks=[cp_callback, tensorboard_callback]
#)


model.fit(
    x=train_generator,
    epochs=100,
    verbose=1,
    validation_data=valid_generator,
    batch_size=16,
    callbacks=[cp_callback, tensorboard_callback, tf.keras.callbacks.EarlyStopping(monitor='f1_score',patience=20]
)
# Out:
# Epoch 1/20
#    1/1984 [..............................] - ETA: 5s - loss: 1.0240 - accuracy: 0.6875 - f1_score: 0.3619WARNING:tensorflow:From C:\Users\lasse\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1984 [..............................] - ETA: 8:32 - loss: 0.9182 - accuracy: 0.8125 - f1_score: 0.3929WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1407s vs `on_train_batch_end` time: 0.3726s). Check your callbacks.
# 1984/1984 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.9721 - f1_score: 0.3405
# Epoch 00001: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0001.ckpt
# WARNING:tensorflow:From C:\Users\lasse\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\lasse\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0001.ckpt\assets
# 1984/1984 [==============================] - 996s 502ms/step - loss: 0.4103 - accuracy: 0.9721 - f1_score: 0.3405 - val_loss: 0.1841 - val_accuracy: 0.9846 - val_f1_score: 0.3307
# Epoch 2/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9794 - f1_score: 0.3339
# Epoch 00002: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0002.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0002.ckpt\assets
# 1984/1984 [==============================] - 1002s 505ms/step - loss: 0.2293 - accuracy: 0.9794 - f1_score: 0.3339 - val_loss: 0.1444 - val_accuracy: 0.9836 - val_f1_score: 0.3306
# Epoch 3/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9811 - f1_score: 0.3326
# Epoch 00003: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0003.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0003.ckpt\assets
# 1984/1984 [==============================] - 1000s 504ms/step - loss: 0.1496 - accuracy: 0.9811 - f1_score: 0.3326 - val_loss: 0.1085 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 4/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9841 - f1_score: 0.3307
# Epoch 00004: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0004.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0004.ckpt\assets
# 1984/1984 [==============================] - 999s 503ms/step - loss: 0.1050 - accuracy: 0.9841 - f1_score: 0.3307 - val_loss: 0.1133 - val_accuracy: 0.9849 - val_f1_score: 0.3308
# Epoch 5/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0933 - accuracy: 0.9848 - f1_score: 0.3308
# Epoch 00005: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0005.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0005.ckpt\assets
# 1984/1984 [==============================] - 999s 504ms/step - loss: 0.0933 - accuracy: 0.9848 - f1_score: 0.3308 - val_loss: 0.0907 - val_accuracy: 0.9836 - val_f1_score: 0.3306
# Epoch 6/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0871 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00006: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0006.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0006.ckpt\assets
# 1984/1984 [==============================] - 999s 504ms/step - loss: 0.0871 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0906 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 7/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0876 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00007: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0007.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0007.ckpt\assets
# 1984/1984 [==============================] - 1000s 504ms/step - loss: 0.0876 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.1154 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 8/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00008: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0008.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0008.ckpt\assets
# 1984/1984 [==============================] - 1003s 506ms/step - loss: 0.0884 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0871 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 9/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00009: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0009.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0009.ckpt\assets
# 1984/1984 [==============================] - 1002s 505ms/step - loss: 0.0859 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0855 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 10/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00010: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0010.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0010.ckpt\assets
# 1984/1984 [==============================] - 1001s 505ms/step - loss: 0.0868 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0951 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 11/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00011: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0011.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0011.ckpt\assets
# 1984/1984 [==============================] - 1004s 506ms/step - loss: 0.0886 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0879 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 12/20
# 1981/1984 [============================>.] - ETA: 1s - loss: 0.0859 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00012: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0012.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0012.ckpt\assets
# 1984/1984 [==============================] - 998s 503ms/step - loss: 0.0863 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0904 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 13/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00013: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0013.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0013.ckpt\assets
# 1984/1984 [==============================] - 1000s 504ms/step - loss: 0.0868 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0842 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 14/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0844 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00014: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0014.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0014.ckpt\assets
# 1984/1984 [==============================] - 1000s 504ms/step - loss: 0.0844 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0882 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 15/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00015: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0015.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0015.ckpt\assets
# 1984/1984 [==============================] - 1001s 505ms/step - loss: 0.0870 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0860 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 16/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00016: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0016.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0016.ckpt\assets
# 1984/1984 [==============================] - 1002s 505ms/step - loss: 0.0853 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0873 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 17/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00017: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0017.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0017.ckpt\assets
# 1984/1984 [==============================] - 1001s 505ms/step - loss: 0.0877 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0914 - val_accuracy: 0.9849 - val_f1_score: 0.3308
# Epoch 18/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00018: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0018.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0018.ckpt\assets
# 1984/1984 [==============================] - 1002s 505ms/step - loss: 0.0846 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0849 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 19/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00019: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0019.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0019.ckpt\assets
# 1984/1984 [==============================] - 1002s 505ms/step - loss: 0.0855 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0839 - val_accuracy: 0.9850 - val_f1_score: 0.3308
# Epoch 20/20
# 1984/1984 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9850 - f1_score: 0.3308
# Epoch 00020: saving model to checkpoints/SOLARPANELS-20210503-103900\cp-0020.ckpt
# INFO:tensorflow:Assets written to: checkpoints/SOLARPANELS-20210503-103900\cp-0020.ckpt\assets
# 1984/1984 [==============================] - 1001s 505ms/step - loss: 0.0846 - accuracy: 0.9850 - f1_score: 0.3308 - val_loss: 0.0891 - val_accuracy: 0.9850 - val_f1_score: 0.3308

# %%
model.save(r'C:\Users\lasse\Desktop\ResNetTest')
# Out:
# INFO:tensorflow:Assets written to: C:\Users\lasse\Desktop\ResNetTest\assets

# %% [markdown]
# ## Evaluating the CNN

# %%
f1 = tfa.metrics.F1Score(3,'macro')

# %%
new_model = tf.keras.models.load_model(r'C:\Users\lasse\Desktop\ResNetTest', custom_objects={'F1Score': f1})
new_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[f1, 'acc'])

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    directory=r"C:\Users\lasse\Desktop\Resnets\ResNet1\Test\\",
    target_size=(256, 256),
    color_mode="rgb",
    batch_size=16,
    class_mode=None,
    shuffle=True,
    seed=42
)
# Out:
# Found 4532 images belonging to 3 classes.

# %%
predict = new_model.evaluate_generator(test_generator, verbose=1)

# %%
a = 0
for i in range(1040):
    img = cv2.imread(r'C:\Users\lasse\Desktop\Dataset1\Finger-failure\Image_%s.png' % (i))
    if img is None:
        print(i)
    else:
        os.rename(r'C:\Users\lasse\Desktop\Dataset1\Finger-failure\Image_%s.png' % (i), r'C:\Users\lasse\Desktop\Dataset1\Finger-failure\Image_%s.png' % (a))
        a = a + 1
